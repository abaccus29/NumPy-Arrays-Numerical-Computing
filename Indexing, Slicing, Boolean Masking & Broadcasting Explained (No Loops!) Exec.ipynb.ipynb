# %%
Practice 1
Create nums = np.arange(0, 50, 5)
Print:

elements from index 2 to 7 (inclusive)
every 2nd element starting from index 1
reverse the array

Practice 2
Create values = np.array([3.2, 7.8, -1.5, 9.1, 0.0, 4.4, -8.2, 12.0])

Show only positive values
Replace negatives with 0
Show values between 5 and 10 (inclusive)

Practice 3
Create heights_cm = np.array([165, 178, 152, 190, 170, 145, 182])
Convert to meters (divide by 100), round to 2 decimals
Practice 4
Create sales = np.array([1200, 800, 1500, 300, 950, 2000, 600])

Find days with sales > 1000
Calculate total sales
Calculate average sales on high-sales days

Practice 5 (challenge)
Create die_rolls = np.random.randint(1, 7, size=20)
Count how many 6s appeared (use == + sum() or np.count_nonzero)

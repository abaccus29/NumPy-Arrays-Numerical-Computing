# %% [markdown]
# <h3>Practice 1</h3>

# %% [markdown]
# <p>Create a 4×5 matrix filled with zeros.<br>
# Add the vector [10, 20, 30, 40, 50] to every row.</p>

# %% [markdown]
# <h3>Practice 2</h3>

# %% [markdown]
# Create a 6×3 matrix of random integers 1–100.<br>
# Subtract the mean of each column from every element in that column.

# %% [markdown]
# <h3>Practice 3</h3>

# %% [markdown]
# Create base = np.array([[1, 2], [3, 4]]) (shape 2×2)<br>
# Create multipliers = np.array([10, 100]) (shape (2,))<br>
# Multiply each row by its multiplier using broadcasting.

# %% [markdown]
# <h3>Practice 4</h3>

# %% [markdown]
# Create a 5×5 matrix of ones.<br>
# Set the entire border (first & last row + first & last column) to 99 using broadcasting + slicing.
